# %%
from PIL import Image

img = Image.open('img/War-Cat.jpg').convert('RGB') # Foto yang saya Save terjadi error karena tidak RGB sehingga perlu dilakukan Convert
img.show() # tampilkan gambar
display(img) # metode alternatif tampilkan gambar
# Out:
# <PIL.Image.Image image mode=RGB size=497x498>

# %%
# Ekstrak setiap channel red, green, blue

r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# 256
# [0, 3122, 3148, 0, 0, 0, 2456, 0, 0, 1012, 2389, 1591, 0, 0, 0, 0, 1175, 0, 0, 0, 0, 0, 4302, 0, 0, 1510, 0, 0, 0, 1080, 2504, 0, 1401, 0, 0, 0, 983, 1745, 1837, 1032, 1001, 0, 0, 1655, 2688, 0, 0, 0, 0, 2084, 1746, 1099, 2225, 2366, 1394, 818, 2669, 1345, 0, 0, 0, 1586, 3081, 3809, 0, 0, 0, 0, 2446, 3872, 1651, 0, 0, 1452, 2375, 3950, 4123, 2929, 0, 0, 0, 1042, 0, 2609, 3787, 2218, 2411, 1122, 972, 2290, 965, 3261, 425, 333, 828, 0, 0, 6321, 3142, 0, 1669, 0, 0, 744, 1933, 2965, 0, 2810, 742, 1415, 1464, 805, 790, 0, 2378, 1832, 829, 292, 2823, 1700, 377, 0, 667, 1673, 1945, 2809, 0, 3152, 0, 713, 1103, 0, 655, 0, 0, 1317, 2007, 4828, 0, 0, 0, 1059, 1558, 0, 3178, 726, 1353, 838, 478, 2160, 669, 1664, 0, 0, 0, 4524, 1462, 937, 0, 0, 0, 0, 3515, 1006, 256, 0, 0, 0, 1155, 1644, 950, 1073, 805, 0, 0, 762, 1186, 0, 0, 469, 1599, 859, 1875, 1314, 706, 0, 403, 0, 1000, 833, 0, 0, 2346, 2324, 1107, 0, 0, 0, 939, 1073, 0, 3179, 0, 586, 923, 0, 0, 0, 0, 0, 2566, 634, 0, 3233, 0, 0, 0, 0, 0, 3038, 1062, 0, 0, 1232, 0, 4034, 0, 0, 0, 1460, 0, 2295, 0, 0, 0, 0, 0, 1862, 0, 0, 0, 1811, 0, 0, 0, 0, 3636, 0, 0, 4336, 0, 0, 0, 0, 0, 0]
