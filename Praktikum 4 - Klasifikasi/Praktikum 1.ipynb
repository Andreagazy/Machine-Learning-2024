# %%
# import library
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=50, centers=3, random_state=0, cluster_std=0.60)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.datasets import make_blobs
#       2 X, y = make_blobs(n_samples=50, centers=3, random_state=0, cluster_std=0.60)
# ----> 3 plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
#
# NameError: name 'plt' is not defined

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plt.plot([0.6], [2.1], 'x', color='red', markeredgewidth=2, markersize=10)

for m, b in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
    plt.plot(xfit, m * xfit + b, '-k')

plt.xlim(-1, 3.5)
# Out:
# (-1.0, 3.5)

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
    yfit = m * xfit + b
    plt.plot(xfit, yfit, '-k')
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',
                    color='#AAAAAA', alpha=0.4)

plt.xlim(-1, 3.5)
# Out:
# (-1.0, 3.5)

# %%
from sklearn.svm import SVC # "Support vector classifier"
model = SVC(kernel='linear', C=1E10)
model.fit(X, y)
# Out:
# SVC(C=10000000000.0, kernel='linear')

# %%
SVC(C=10000000000.0, kernel='linear')
# Out:
# SVC(C=10000000000.0, kernel='linear')

# %%
# buat sebuah fungsi untuk menampilkan fitting data

def plot_svc_decision_function(model, ax=None, plot_support=True):
    
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # buat grid untuk evaluasi model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    # plot batas dan margin
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model)

# %%
# untuk mengetahui data yang masuk ke dalam support vector dapat dilakukan dengan memanggil support_vectors_

model.support_vectors_
# Out:
# array([[0.44359863, 3.11530945],
#        [2.33812285, 3.43116792],
#        [2.06156753, 1.96918596]])

# %%
def plot_svm(N=10, ax=None):
    X, y = make_blobs(n_samples=200, centers=2,
                      random_state=0, cluster_std=0.60)
    X = X[:N]
    y = y[:N]
    model = SVC(kernel='linear', C=1E10)
    model.fit(X, y)
    
    ax = ax or plt.gca()
    ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
    ax.set_xlim(-1, 4)
    ax.set_ylim(-1, 6)
    plot_svc_decision_function(model, ax)

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)
for axi, N in zip(ax, [60, 120]):
    plot_svm(N, axi)
    axi.set_title('N = {0}'.format(N))

# %%
# contoh data tidak terpisah secara linier

from sklearn.datasets import make_circles
X, y = make_circles(100, factor=.1, noise=.1)

clf = SVC(kernel='linear').fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);

# %%
r = np.exp(-(X ** 2).sum(1))

# %%
from mpl_toolkits import mplot3d
from ipywidgets import interact, fixed

r = np.sqrt(X[:, 0] ** 2 + X[:, 1] ** 2)

def plot_3D(elev=30, azim=30, X=X, y=y):
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=50, cmap='autumn')
    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('r')

interact(plot_3D, elev=[-90, 45, 30, 20, 10], azim=(-180, 180), X=fixed(X), y=fixed(y))
# Out:
# interactive(children=(Dropdown(description='elev', index=2, options=(-90, 45, 30, 20, 10), value=30), IntSlide…
# <function __main__.plot_3D(elev=30, azim=30, X=array([[-9.20829802e-01, -4.16195362e-01],
#        [-1.12675064e+00, -2.16103637e-01],
#        [ 2.76810620e-01,  8.68300268e-02],
#        [ 1.06767758e-01,  8.59309375e-01],
#        [-4.05190904e-02,  2.25155588e-02],
#        [ 8.95778842e-01,  2.13093003e-02],
#        [ 5.18674198e-01,  1.01029490e+00],
#        [ 7.56140711e-02,  3.96674801e-04],
#        [-1.62729975e-01,  7.57073481e-02],
#        [-9.08290014e-01,  1.85753080e-01],
#        [ 1.03603665e-01,  1.18580365e-01],
#        [-1.35072721e-01,  1.02225284e-01],
#        [ 5.04981326e-01, -8.85900368e-01],
#        [ 8.76795785e-02, -3.88114569e-02],
#        [ 1.72988467e-01,  9.64908135e-02],
#        [ 3.48219390e-02,  9.64307869e-01],
#        [ 1.79151580e-01,  6.87488862e-02],
#        [-3.39632400e-02, -2.66965192e-01],
#        [-2.22866763e-01, -9.64083573e-02],
#        [ 7.16247862e-03, -8.38597465e-02],
#        [ 3.32540570e-01,  9.22015846e-01],
#        [-3.91095439e-02,  1.31539353e-01],
#        [ 5.77806789e-01,  8.69106537e-01],
#        [ 9.38583958e-02,  1.66717801e-01],
#        [-2.81894643e-01, -9.08175028e-01],
#        [ 8.85322609e-01, -4.70791281e-01],
#        [ 1.07480588e+00, -4.27329848e-01],
#        [ 1.05225833e+00,  1.52253258e-01],
#        [ 8.56990062e-02,  9.84688691e-02],
#        [-2.13025536e-02,  8.38851016e-02],
#        [-6.38137104e-01,  7.80730176e-01],
#        [ 1.26070386e-01,  6.41186740e-02],
#        [-7.81451172e-02, -5.68302915e-02],
#        [ 8.28519719e-01, -4.90277701e-01],
#        [ 4.86580797e-01, -9.52411022e-01],
#        [-8.56752406e-01,  6.98952145e-01],
#        [ 6.20990965e-02, -3.94177967e-02],
#        [-4.88463418e-01, -1.02696834e+00],
#        [ 2.63994559e-01, -7.38047183e-01],
#        [-3.98346669e-01,  8.42162299e-01],
#        [-1.14959868e-01,  6.18110474e-02],
#        [ 8.91415104e-01,  5.60594636e-01],
